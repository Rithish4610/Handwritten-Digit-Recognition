# %% [markdown]
# # Import Required Libraries
# Import TensorFlow, Keras, NumPy, and Matplotlib for building and evaluating the digit recognition model.

# %%
# Import Required Libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Import Required Libraries
# ----> 2 import tensorflow as tf
#       3 from tensorflow import keras
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# # Load and Preprocess the MNIST Dataset
# Load the MNIST dataset, normalize pixel values, and reshape data for model input.

# %%
# Load and Preprocess the MNIST Dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# # Build the Digit Recognition Model
# Define a sequential neural network model using Keras with appropriate layers for digit classification.

# %%
# Build the Digit Recognition Model
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Build the Digit Recognition Model
# ----> 2 model = keras.Sequential([
#       3     keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
#       4     keras.layers.MaxPooling2D((2, 2)),
#       5     keras.layers.Conv2D(64, (3, 3), activation='relu'),
#       6     keras.layers.MaxPooling2D((2, 2)),
#       7     keras.layers.Flatten(),
#       8     keras.layers.Dense(64, activation='relu'),
#       9     keras.layers.Dense(10, activation='softmax')
#      10 ])
#
# NameError: name 'keras' is not defined

# %% [markdown]
# # Train the Model
# Compile and train the model using the training data, displaying training progress and accuracy.

# %%
# Train the Model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# %% [markdown]
# # Evaluate Model Performance
# Evaluate the trained model on the test dataset and display metrics such as accuracy.

# %%
# Evaluate Model Performance
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc:.4f}')

# %% [markdown]
# # Save the Trained Model
# Save the trained model to a file (model.h5) for later use.

# %%
# Save the Trained Model
model.save('model.h5')

# %% [markdown]
# # Load and Use the Saved Model for Prediction
# Load the saved model and use it to predict digits from new or test images.

# %%
# Load and Use the Saved Model for Prediction
loaded_model = keras.models.load_model('model.h5')
predictions = loaded_model.predict(x_test)
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f'Predicted: {np.argmax(predictions[i])}')
    plt.axis('off')
plt.tight_layout()
plt.show()
